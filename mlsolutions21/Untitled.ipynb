# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/data/datasets/auto-mpg.csv')

# %%
a = df[['mpg', 'cylinders', 'weight']].to_numpy()

# %%
a.shape
# Out:
# (398, 3)

# %%
pd.DataFrame(a, columns=['mpg', 'a', 'b'])
# Out:
#       mpg    a       b
# 0    18.0  8.0  3504.0
# 1    15.0  8.0  3693.0
# 2    18.0  8.0  3436.0
# 3    16.0  8.0  3433.0
# 4    17.0  8.0  3449.0
# 5    15.0  8.0  4341.0
# 6    14.0  8.0  4354.0
# 7    14.0  8.0  4312.0
# 8    14.0  8.0  4425.0
# 9    15.0  8.0  3850.0
# 10   15.0  8.0  3563.0
# 11   14.0  8.0  3609.0
# 12   15.0  8.0  3761.0
# 13   14.0  8.0  3086.0
# 14   24.0  4.0  2372.0
# 15   22.0  6.0  2833.0
# 16   18.0  6.0  2774.0
# 17   21.0  6.0  2587.0
# 18   27.0  4.0  2130.0
# 19   26.0  4.0  1835.0
# 20   25.0  4.0  2672.0
# 21   24.0  4.0  2430.0
# 22   25.0  4.0  2375.0
# 23   26.0  4.0  2234.0
# 24   21.0  6.0  2648.0
# 25   10.0  8.0  4615.0
# 26   10.0  8.0  4376.0
# 27   11.0  8.0  4382.0
# 28    9.0  8.0  4732.0
# 29   27.0  4.0  2130.0
# ..    ...  ...     ...
# 368  27.0  4.0  2640.0
# 369  34.0  4.0  2395.0
# 370  31.0  4.0  2575.0
# 371  29.0  4.0  2525.0
# 372  27.0  4.0  2735.0
# 373  24.0  4.0  2865.0
# 374  23.0  4.0  3035.0
# 375  36.0  4.0  1980.0
# ...
