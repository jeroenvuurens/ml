# %% [markdown]
# # Decision Tree

# %% [markdown]
# Decision trees iteratively split the population according to decision rules, e.g. gender, income, to identify groups that ideally all belong to the same class, e.g. political preference.

# %% [markdown]
# # Data
#
# For this, we can load the dataset with the `wines_classify` function in which we set the minimum quality for a wine to pass. A 2d scatter plot uses the colors green for the wines with a quality >= threshold and the color red for the wines that do not. We can roughly see that wines are better appreciated when containing more alcohol and being slightly more acidic.

# %%
from ml import *

# %%
data = wines_binary('quality', 'alcohol', 'pH', threshold=6)

# %%
data.plot2d()

# %% [markdown]
# # Model, Training and Validation
#
# The difference in code is just choosing a different model. You can use the decision_tree model and can set the max_depth parameter to allow the model to use more decision rules and thus create a more complex model.

# %%
model = decision_tree(data, max_depth=4)
model.train()
model.data.plot2d()
model.plot_boundary()
# Out:
# ...
# 1 0.00s train loss: 0.007094  acc: 0.737295 valid loss: 0.040138  acc: 0.628125

# %% [markdown]
# #### Try to rerun the experiment, what setting of max_depth gives the best results?
