# %%
from ml import *

# %%
data = advertising_sales()

# %%
model = linear_regression_ne(data)
model.train()
data.plot()
model.plot_train_line()
# Out:
# ...
# 0 0.00s train loss: 2.896956 valid loss: 1.990188
