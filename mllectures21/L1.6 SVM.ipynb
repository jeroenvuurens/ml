# %%
from ml import *

# %%
data = iris_classify()
data.plot2d()

# %%
model = svm(data)
model.train()
data.plot2d()
model.plot_boundary()
# Out:
# ...
# 0 0.00s train loss: 0.037777  acc: 0.912500 valid loss: 0.086349  acc: 0.950000
