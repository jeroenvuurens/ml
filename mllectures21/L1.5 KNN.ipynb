# %%
from ml import *

# %%
data = iris_classify(scale=True)
data.plot2d()

# %%
model = knn(data, k=1)
model.train()
data.plot2d()
model.plot_boundary()
# Out:
# ...
# 0 0.00s train loss: 0.431745  acc: 0.987500 valid loss: 0.000000  acc: 1.000000
