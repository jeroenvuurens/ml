# %%
from ml import *

# %%
data = advertising_profit_tv(degree = 2)

# %%
model = linear_regression_ne(data )
model.train()
data.plot()
model.plot_train_line()
# Out:
# ...
# 0 0.00s train loss: 1353.449864 valid loss: 1472.547199
