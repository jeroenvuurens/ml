# %%
from ml import *

# %%
data = iris_classify()
data.plot2d()

# %%
model = decision_tree(data, max_depth=40)
model.train()
data.plot2d()
model.plot_boundary()
# Out:
# ...
# 0 0.00s train loss: 0.005397  acc: 0.987500 valid loss: 0.086349  acc: 0.950000
