# %%
from pipetorch import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bb686caf5d12> in <module>
# ----> 1 from pipetorch import *
#
# /opt/jupyterhub/anaconda/lib/python3.6/site-packages/pipetorch-0.1-py3.6.egg/pipetorch/__init__.py in <module>
# ----> 1 from .pipetorch import *
#       2 from .version import __version__
#       3 import numpy as np
#       4 import pandas as pd
#       5 from sklearn.preprocessing import StandardScaler, PolynomialFeatures
#
# ModuleNotFoundError: No module named 'pipetorch.pipetorch'

# %%
from ml import *

# %%
data = advertising('Sales', 'Radio', 'TV')

# %%
data.plot()

# %%
model = linear_regression_ne(data)

# %%
model.train()
# Out:
# ...
# 0 0.00s train loss: 2.904611 valid loss: 1.927272

# %%
model.data.plot()
model.plot_train_line()

# %% [markdown]
# # Model parameters
#
# We can also inspect the learned coefficients. In this case, it has learned a function `sales = 0.055 * tv_advertising + 6.97`.

# %%
model.parameters()
# Out:
# array([4.65467165, 0.10549896, 0.05424014])
